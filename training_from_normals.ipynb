# %% [markdown]
# # Détection de gravure par Deep Learning
# ### Premier modèle : 1 gravure par image
# On donne une carte de normale en entrée au réseau

# %% [markdown]
# ### Dataset
#
# J'utilise le dataset que j'ai créé à cet effet.
#
# Il est en local sur ma machine actuellement

# %%
# !nvidia-smi
# Out:
# Thu Jul 24 15:04:12 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Quadro RTX 5000                Off |   00000000:73:00.0  On |                  Off |
# | 33%   34C    P8             23W /  230W |     350MiB /  16384MiB |     38%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      3994      G   /usr/lib/xorg/Xorg                             39MiB |
# |    0   N/A  N/A    342152      G   /usr/lib/xorg/Xorg                            105MiB |
# |    0   N/A  N/A    342281      G   /usr/bin/gnome-shell                           93MiB |
# |    0   N/A  N/A    344870      G   /proc/self/exe                                 92MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Préparation des données

# %%
# groundtruth_folder = 'dataset_masdazil_1/grav'
# data_folder = 'dataset_masdazil_1/mu'
groundtruth_folder = 'dataset/dataset_masdazil_3/gravures'
data_folder = 'dataset/dataset_masdazil_3/murs'

# %%
import os
from sklearn.model_selection import train_test_split

# Get the list of groundtruth and data files
groundtruth_files = sorted(os.listdir(groundtruth_folder))
data_files = sorted(os.listdir(data_folder))

# Create pairs: for each groundtruth "something.png", match all data files "something_i.png"
data_pairs = []
for gt_file in groundtruth_files:
  base_name = os.path.splitext(gt_file)[0]  # "something"
  matching_data_files = [f for f in data_files if (f.startswith(base_name+"_") or f.startswith(base_name+"."))  and f.endswith('.png')]
  for file in matching_data_files:
    data_pairs.append((os.path.join(groundtruth_folder, gt_file), os.path.join(data_folder, file)))

# Split the data into training, validation, and test sets
# Let's use a split of 70% training, 15% validation, 15% testing
train_val_data, test_data = train_test_split(data_pairs, test_size=0.10, random_state=42)
train_data, val_data = train_test_split(train_val_data, test_size=(0.10 / 0.90), random_state=42) # Adjust test_size for the remaining data

print(f"Total data pairs: {len(data_pairs)}")
print(f"Training data pairs: {len(train_data)}")
print(f"Validation data pairs: {len(val_data)}")
print(f"Test data pairs: {len(test_data)}")
# Out:
# Total data pairs: 252
# Training data pairs: 200
# Validation data pairs: 26
# Test data pairs: 26

# %%
from tensorflow.keras.utils import Sequence
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import tensorflow as tf

class DataGenerator(Sequence):
    def __init__(self, data_pairs, batch_size, img_height, img_width, img_channels, data_folder, groundtruth_folder, shuffle=True):
        self.data_pairs = data_pairs
        self.batch_size = batch_size
        self.img_height = img_height
        self.img_width = img_width
        self.img_channels = img_channels
        self.data_folder = data_folder
        self.groundtruth_folder = groundtruth_folder
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.data_pairs) / self.batch_size))

    def __getitem__(self, index):
        batch_pairs = self.data_pairs[index*self.batch_size:(index+1)*self.batch_size]
        images = []
        masks = []
        for mask_path, img_path in batch_pairs:
            img = load_img(img_path, target_size=(self.img_height, self.img_width), color_mode="rgb")
            mask = load_img(mask_path, target_size=(self.img_height, self.img_width), color_mode="grayscale")
            #images.append(img_to_array(img) / 255.0)
            images.append((img_to_array(img) - 127.5) / 127.5)  # Normalize to [-1, 1])
            masks.append(1 - img_to_array(mask) / 255.0)
        X = tf.convert_to_tensor(np.array(images), dtype=tf.float32)
        y = tf.cast(np.array(masks), tf.float32)
        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.data_pairs)

# %% [markdown]
# ### Modèle

# %%
IMG_HEIGHT = 512
IMG_WIDTH = 512
IMG_CHANNELS = 3  # 1 for grayscale
BATCH_SIZE = 16

# %%
from tensorflow.keras.layers import Input, Conv2D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.layers import MaxPooling2D, Conv2DTranspose

def build_unet(input_shape):
    # For 2D RGB input (batch, height, width, channels), use Conv2D, MaxPooling2D, etc.
    # receptive field ~= 100x100

    inputs = Input(input_shape)

    # Downsampling
    c1 = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    c1 = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p1)
    c2 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p2)
    c3 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    # Bottleneck
    b = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p3)
    b = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(b)

    # Upsampling
    u3 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same', kernel_initializer='he_normal')(b)
    u3 = concatenate([u3, c3])
    c4 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u3)
    c4 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c4)

    u2 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same', kernel_initializer='he_normal')(c4)
    u2 = concatenate([u2, c2])
    c5 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u2)
    c5 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c5)

    u1 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same', kernel_initializer='he_normal')(c5)
    u1 = concatenate([u1, c1])
    c6 = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u1)
    c6 = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c6)

    outputs = Conv2D(1, (1, 1), activation='sigmoid', kernel_initializer='he_normal')(c6)

    return Model(inputs, outputs)

def build_unet_big(input_shape):
    # receptive field ~= 800x800
    # For 2D RGB input (batch, height, width, channels), use Conv2D, MaxPooling2D, etc.

    inputs = Input(input_shape)
    # Downsampling
    c1 = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    c1 = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p1)
    c2 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p2)
    c3 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p3)
    c4 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p4)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c5)
    p5 = MaxPooling2D((2, 2))(c5)

    # c6 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p5)
    # c6 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c6)
    # p6 = MaxPooling2D((2, 2))(c6)

    # Bottleneck
    b = Conv2D(1024, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(p5)
    b = Conv2D(1024, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(b)

    # Upsampling
    # u6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same', kernel_initializer='he_normal')(b)
    # u6 = concatenate([u6, c6])
    # c7 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u6)
    # c7 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c7)

    u5 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same', kernel_initializer='he_normal')(b)
    u5 = concatenate([u5, c5])
    c8 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u5)
    c8 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c8)

    u4 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same', kernel_initializer='he_normal')(c8)
    u4 = concatenate([u4, c4])
    c9 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u4)
    c9 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c9)

    u3 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same', kernel_initializer='he_normal')(c9)
    u3 = concatenate([u3, c3])
    c10 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u3)
    c10 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c10)

    u2 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same', kernel_initializer='he_normal')(c10)
    u2 = concatenate([u2, c2])
    c11 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u2)
    c11 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c11)

    u1 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same', kernel_initializer='he_normal')(c11)
    u1 = concatenate([u1, c1])
    c12 = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(u1)
    c12 = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(c12)

    outputs = Conv2D(1, (1, 1), activation='sigmoid', kernel_initializer='he_normal')(c12)

    return Model(inputs, outputs)

model = build_unet_big((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv2d_23 (Conv2D)          (None, 512, 512, 16)         448       ['input_2[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 512, 512, 16)         2320      ['conv2d_23[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 256, 256, 16)         0         ['conv2d_24[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 256, 256, 32)         4640      ['max_pooling2d_5[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 256, 256, 32)         9248      ['conv2d_25[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 128, 128, 32)         0         ['conv2d_26[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 128, 128, 64)         18496     ['max_pooling2d_6[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 128, 128, 64)         36928     ['conv2d_27[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 64, 64, 64)           0         ['conv2d_28[0][0]']
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 128)          73856     ['max_pooling2d_7[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 128)          147584    ['conv2d_29[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 32, 32, 128)          0         ['conv2d_30[0][0]']
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 256)          295168    ['max_pooling2d_8[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 256)          590080    ['conv2d_31[0][0]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 16, 16, 256)          0         ['conv2d_32[0][0]']
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 1024)         2360320   ['max_pooling2d_9[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 1024)         9438208   ['conv2d_33[0][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 32, 32, 256)          1048832   ['conv2d_34[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 32, 32, 512)          0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'conv2d_32[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 32, 32, 256)          1179904   ['concatenate_5[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 256)          590080    ['conv2d_35[0][0]']
#
#  conv2d_transpose_6 (Conv2D  (None, 64, 64, 128)          131200    ['conv2d_36[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 64, 64, 256)          0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'conv2d_30[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 64, 64, 128)          295040    ['concatenate_6[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 64, 64, 128)          147584    ['conv2d_37[0][0]']
#
#  conv2d_transpose_7 (Conv2D  (None, 128, 128, 64)         32832     ['conv2d_38[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 128, 128, 128)        0         ['conv2d_transpose_7[0][0]',
#  )                                                                   'conv2d_28[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 128, 128, 64)         73792     ['concatenate_7[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 128, 128, 64)         36928     ['conv2d_39[0][0]']
#
#  conv2d_transpose_8 (Conv2D  (None, 256, 256, 32)         8224      ['conv2d_40[0][0]']
#  Transpose)
#
#  concatenate_8 (Concatenate  (None, 256, 256, 64)         0         ['conv2d_transpose_8[0][0]',
#  )                                                                   'conv2d_26[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 256, 256, 32)         18464     ['concatenate_8[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 256, 256, 32)         9248      ['conv2d_41[0][0]']
#
#  conv2d_transpose_9 (Conv2D  (None, 512, 512, 16)         2064      ['conv2d_42[0][0]']
#  Transpose)
#
#  concatenate_9 (Concatenate  (None, 512, 512, 32)         0         ['conv2d_transpose_9[0][0]',
#  )                                                                   'conv2d_24[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 512, 512, 16)         4624      ['concatenate_9[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 512, 512, 16)         2320      ['conv2d_43[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 512, 512, 1)          17        ['conv2d_44[0][0]']
#
# ==================================================================================================
# Total params: 16558449 (63.17 MB)
# Trainable params: 16558449 (63.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# #### Champ réceptif du modèle

# %%
import numpy as np
import tensorflow as tf

# Initialiser uniquement les coefficients (poids) du modèle à 1, laisser les biais inchangés
for layer in model.layers:
    if hasattr(layer, 'kernel_initializer'):
        weights = layer.get_weights()
        if weights:
            # Généralement, le premier élément est le kernel, le second le biais (si présent)
            new_weights = []
            for i, w in enumerate(weights):
                if i == 0:  # kernel/coefficients
                    new_weights.append(np.ones(w.shape, dtype=w.dtype))
                else:  # biais ou autres
                    new_weights.append(w)
            layer.set_weights(new_weights)

# Créer une image noire avec un pixel blanc au centre
input_img = np.zeros((1, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.float32)
center_h = IMG_HEIGHT // 2
center_w = IMG_WIDTH // 2
input_img[0, center_h, center_w, :] = 1.0

# Prédiction
output = model.predict(input_img)[0, ..., 0]

import matplotlib.pyplot as plt
plt.imshow(output, cmap='hot')
plt.title("Sortie du modèle (champ réceptif)")
plt.colorbar()
plt.show()
# Out:
# 1/1 [==============================] - 0s 369ms/step

# %% [markdown]
# ### Training

# %%
# Losses
def dice_loss(y_true, y_pred, smooth=1e-8):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true*y_pred, axis=[1,2,3])
    
    # union = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    # dice = (2. * intersection + smooth) / (union + smooth)

    den1 = tf.reduce_sum(y_true * y_true, axis=[1, 2, 3])
    den2 = tf.reduce_sum(y_pred * y_pred, axis=[1, 2, 3])
    dice = (2. * intersection + smooth) / (den1 + den2 + smooth)

    return 1 - tf.reduce_mean(dice)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return bce + dice

def focal_dice_loss(y_true, y_pred, lambda_bfce=1.0):
    bfce = tf.keras.losses.BinaryFocalCrossentropy()(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return lambda_bfce * bfce + dice

# Metrics
def f1_score_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    tp = tf.reduce_sum(y_true * y_pred)
    fp = tf.reduce_sum((1 - y_true) * y_pred)
    fn = tf.reduce_sum(y_true * (1 - y_pred))
    precision = tp / (tp + fp + 1e-6)
    recall = tp / (tp + fn + 1e-6)
    f1 = 2 * precision * recall / (precision + recall + 1e-6)
    return f1

# Callbacks
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint(filepath=f'checkpoints/best.weights.h5', save_weights_only=True, save_best_only=True, monitor='loss', mode='min', verbose=1)
early_stopping = EarlyStopping(monitor='loss', patience=10, mode='min', verbose=1)

# %%
train_gen = DataGenerator(train_data, BATCH_SIZE, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, data_folder, groundtruth_folder)
val_gen = DataGenerator(val_data, BATCH_SIZE, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, data_folder, groundtruth_folder, shuffle=False)
test_gen = DataGenerator(test_data, BATCH_SIZE, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, data_folder, groundtruth_folder, shuffle=False)

whole_gen = DataGenerator(data_pairs, BATCH_SIZE, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, data_folder, groundtruth_folder)

# %% [markdown]
# #### Learning rate Schedulers

# %%
import tensorflow_addons as tfa

learning_rate_start = 1e-1
learning_rate_end = 1e-4

lr_schedule_poly = tf.keras.optimizers.schedules.PolynomialDecay(
    initial_learning_rate=learning_rate_start,
    decay_steps=500,
    end_learning_rate=learning_rate_end,
    power=1.0
)

lr_schedule_exp = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate_start,
    decay_steps=500,
    decay_rate= learning_rate_end / learning_rate_start,
    staircase=False
)

steps_per_epoch = len(train_data) // BATCH_SIZE
lr_schedule_cycle = tfa.optimizers.CyclicalLearningRate(
    initial_learning_rate=learning_rate_start,
    maximal_learning_rate=learning_rate_end,
    step_size=2 * steps_per_epoch,
    scale_fn=lambda x: 1 / (2.0 ** (x - 1)),
    scale_mode='cycle'
)
# Out:
# /home/nrr6650/dev/training/.venv/lib/python3.8/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# #### Fitting model

# %%
adam = tf.keras.optimizers.Adam(learning_rate=1e-3)
adamW = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
rmsprop = tf.keras.optimizers.RMSprop(learning_rate=1e-3)
sgd = tf.keras.optimizers.SGD(learning_rate=lr_schedule_cycle)

adam2 = tf.keras.optimizers.Adam(learning_rate=1e-3, beta_1=0.5, beta_2=0.5, epsilon=1e-07, amsgrad=False)

model.compile(
    optimizer=adam2,
    loss=focal_dice_loss,
    metrics=[f1_score_metric, dice_loss]
)

history = model.fit(
    whole_gen,
    epochs=100,
    # validation_data=val_gen,
    callbacks=[checkpoint, early_stopping]
)

model.save('unet_model_from_normals.h5')

# import gc
# globals().clear()

# # kill the kernel to free up memory
# import os
# os._exit(0)  # This will terminate the kernel and free up memory
# Out:
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 1.4930 - f1_score_metric: 0.0812 - dice_loss: 0.8170
# Epoch 1: loss improved from inf to 1.49301, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 48s 3s/step - loss: 1.4930 - f1_score_metric: 0.0812 - dice_loss: 0.8170
# Epoch 2/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8536 - f1_score_metric: 0.0853 - dice_loss: 0.7948
# Epoch 2: loss improved from 1.49301 to 0.85361, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 49s 3s/step - loss: 0.8536 - f1_score_metric: 0.0853 - dice_loss: 0.7948
# Epoch 3/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8506 - f1_score_metric: 0.0871 - dice_loss: 0.7924
# Epoch 3: loss improved from 0.85361 to 0.85056, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 48s 3s/step - loss: 0.8506 - f1_score_metric: 0.0871 - dice_loss: 0.7924
# Epoch 4/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8461 - f1_score_metric: 0.0903 - dice_loss: 0.7861
# Epoch 4: loss improved from 0.85056 to 0.84610, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 48s 3s/step - loss: 0.8461 - f1_score_metric: 0.0903 - dice_loss: 0.7861
# Epoch 5/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8371 - f1_score_metric: 0.0949 - dice_loss: 0.7784
# Epoch 5: loss improved from 0.84610 to 0.83711, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 48s 3s/step - loss: 0.8371 - f1_score_metric: 0.0949 - dice_loss: 0.7784
# Epoch 6/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8340 - f1_score_metric: 0.0975 - dice_loss: 0.7733
# Epoch 6: loss improved from 0.83711 to 0.83405, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 48s 3s/step - loss: 0.8340 - f1_score_metric: 0.0975 - dice_loss: 0.7733
# Epoch 7/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8282 - f1_score_metric: 0.1001 - dice_loss: 0.7678
# Epoch 7: loss improved from 0.83405 to 0.82819, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.8282 - f1_score_metric: 0.1001 - dice_loss: 0.7678
# Epoch 8/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8288 - f1_score_metric: 0.1018 - dice_loss: 0.7671
# Epoch 8: loss did not improve from 0.82819
# 16/16 [==============================] - 38s 2s/step - loss: 0.8288 - f1_score_metric: 0.1018 - dice_loss: 0.7671
# Epoch 9/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8254 - f1_score_metric: 0.1037 - dice_loss: 0.7635
# Epoch 9: loss improved from 0.82819 to 0.82539, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.8254 - f1_score_metric: 0.1037 - dice_loss: 0.7635
# Epoch 10/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8142 - f1_score_metric: 0.1090 - dice_loss: 0.7534
# Epoch 10: loss improved from 0.82539 to 0.81420, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.8142 - f1_score_metric: 0.1090 - dice_loss: 0.7534
# Epoch 11/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8131 - f1_score_metric: 0.1146 - dice_loss: 0.7475
# Epoch 11: loss improved from 0.81420 to 0.81310, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.8131 - f1_score_metric: 0.1146 - dice_loss: 0.7475
# Epoch 12/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8121 - f1_score_metric: 0.1127 - dice_loss: 0.7477
# Epoch 12: loss improved from 0.81310 to 0.81209, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.8121 - f1_score_metric: 0.1127 - dice_loss: 0.7477
# Epoch 13/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8006 - f1_score_metric: 0.1186 - dice_loss: 0.7378
# Epoch 13: loss improved from 0.81209 to 0.80065, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.8006 - f1_score_metric: 0.1186 - dice_loss: 0.7378
# Epoch 14/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7897 - f1_score_metric: 0.1253 - dice_loss: 0.7253
# Epoch 14: loss improved from 0.80065 to 0.78974, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.7897 - f1_score_metric: 0.1253 - dice_loss: 0.7253
# Epoch 15/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7889 - f1_score_metric: 0.1254 - dice_loss: 0.7252
# Epoch 15: loss improved from 0.78974 to 0.78888, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.7889 - f1_score_metric: 0.1254 - dice_loss: 0.7252
# Epoch 16/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7817 - f1_score_metric: 0.1315 - dice_loss: 0.7158
# Epoch 16: loss improved from 0.78888 to 0.78174, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.7817 - f1_score_metric: 0.1315 - dice_loss: 0.7158
# Epoch 17/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7736 - f1_score_metric: 0.1374 - dice_loss: 0.7074
# Epoch 17: loss improved from 0.78174 to 0.77359, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.7736 - f1_score_metric: 0.1374 - dice_loss: 0.7074
# Epoch 18/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7640 - f1_score_metric: 0.1432 - dice_loss: 0.6976
# Epoch 18: loss improved from 0.77359 to 0.76400, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.7640 - f1_score_metric: 0.1432 - dice_loss: 0.6976
# Epoch 19/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7607 - f1_score_metric: 0.1455 - dice_loss: 0.6959
# Epoch 19: loss improved from 0.76400 to 0.76068, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 40s 2s/step - loss: 0.7607 - f1_score_metric: 0.1455 - dice_loss: 0.6959
# Epoch 20/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7474 - f1_score_metric: 0.1542 - dice_loss: 0.6792
# Epoch 20: loss improved from 0.76068 to 0.74743, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.7474 - f1_score_metric: 0.1542 - dice_loss: 0.6792
# Epoch 21/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7470 - f1_score_metric: 0.1628 - dice_loss: 0.6718
# Epoch 21: loss improved from 0.74743 to 0.74702, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.7470 - f1_score_metric: 0.1628 - dice_loss: 0.6718
# Epoch 22/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7328 - f1_score_metric: 0.1675 - dice_loss: 0.6611
# Epoch 22: loss improved from 0.74702 to 0.73277, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.7328 - f1_score_metric: 0.1675 - dice_loss: 0.6611
# Epoch 23/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7129 - f1_score_metric: 0.1799 - dice_loss: 0.6444
# Epoch 23: loss improved from 0.73277 to 0.71288, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 48s 3s/step - loss: 0.7129 - f1_score_metric: 0.1799 - dice_loss: 0.6444
# Epoch 24/100
# 16/16 [==============================] - ETA: 0s - loss: 0.6883 - f1_score_metric: 0.1966 - dice_loss: 0.6195
# Epoch 24: loss improved from 0.71288 to 0.68833, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.6883 - f1_score_metric: 0.1966 - dice_loss: 0.6195
# Epoch 25/100
# 16/16 [==============================] - ETA: 0s - loss: 0.6823 - f1_score_metric: 0.2050 - dice_loss: 0.6096
# Epoch 25: loss improved from 0.68833 to 0.68230, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.6823 - f1_score_metric: 0.2050 - dice_loss: 0.6096
# Epoch 26/100
# 16/16 [==============================] - ETA: 0s - loss: 0.6448 - f1_score_metric: 0.2284 - dice_loss: 0.5744
# Epoch 26: loss improved from 0.68230 to 0.64480, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.6448 - f1_score_metric: 0.2284 - dice_loss: 0.5744
# Epoch 27/100
# 16/16 [==============================] - ETA: 0s - loss: 0.5983 - f1_score_metric: 0.2617 - dice_loss: 0.5304
# Epoch 27: loss improved from 0.64480 to 0.59832, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.5983 - f1_score_metric: 0.2617 - dice_loss: 0.5304
# Epoch 28/100
# 16/16 [==============================] - ETA: 0s - loss: 0.5854 - f1_score_metric: 0.2819 - dice_loss: 0.5168
# Epoch 28: loss improved from 0.59832 to 0.58539, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.5854 - f1_score_metric: 0.2819 - dice_loss: 0.5168
# Epoch 29/100
# 16/16 [==============================] - ETA: 0s - loss: 0.5475 - f1_score_metric: 0.3089 - dice_loss: 0.4799
# Epoch 29: loss improved from 0.58539 to 0.54752, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.5475 - f1_score_metric: 0.3089 - dice_loss: 0.4799
# Epoch 30/100
# 16/16 [==============================] - ETA: 0s - loss: 0.5213 - f1_score_metric: 0.3300 - dice_loss: 0.4549
# Epoch 30: loss improved from 0.54752 to 0.52129, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.5213 - f1_score_metric: 0.3300 - dice_loss: 0.4549
# Epoch 31/100
# 16/16 [==============================] - ETA: 0s - loss: 0.4999 - f1_score_metric: 0.3449 - dice_loss: 0.4367
# Epoch 31: loss improved from 0.52129 to 0.49988, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.4999 - f1_score_metric: 0.3449 - dice_loss: 0.4367
# Epoch 32/100
# 16/16 [==============================] - ETA: 0s - loss: 0.4795 - f1_score_metric: 0.3680 - dice_loss: 0.4168
# Epoch 32: loss improved from 0.49988 to 0.47951, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.4795 - f1_score_metric: 0.3680 - dice_loss: 0.4168
# Epoch 33/100
# 16/16 [==============================] - ETA: 0s - loss: 0.4650 - f1_score_metric: 0.3777 - dice_loss: 0.4047
# Epoch 33: loss improved from 0.47951 to 0.46497, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.4650 - f1_score_metric: 0.3777 - dice_loss: 0.4047
# Epoch 34/100
# 16/16 [==============================] - ETA: 0s - loss: 0.4438 - f1_score_metric: 0.3984 - dice_loss: 0.3857
# Epoch 34: loss improved from 0.46497 to 0.44385, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.4438 - f1_score_metric: 0.3984 - dice_loss: 0.3857
# Epoch 35/100
# 16/16 [==============================] - ETA: 0s - loss: 0.4300 - f1_score_metric: 0.4078 - dice_loss: 0.3736
# Epoch 35: loss improved from 0.44385 to 0.42995, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.4300 - f1_score_metric: 0.4078 - dice_loss: 0.3736
# Epoch 36/100
# 16/16 [==============================] - ETA: 0s - loss: 0.4044 - f1_score_metric: 0.4333 - dice_loss: 0.3516
# Epoch 36: loss improved from 0.42995 to 0.40445, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.4044 - f1_score_metric: 0.4333 - dice_loss: 0.3516
# Epoch 37/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3762 - f1_score_metric: 0.4661 - dice_loss: 0.3241
# Epoch 37: loss improved from 0.40445 to 0.37622, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.3762 - f1_score_metric: 0.4661 - dice_loss: 0.3241
# Epoch 38/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3758 - f1_score_metric: 0.4585 - dice_loss: 0.3258
# Epoch 38: loss improved from 0.37622 to 0.37584, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.3758 - f1_score_metric: 0.4585 - dice_loss: 0.3258
# Epoch 39/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3483 - f1_score_metric: 0.4874 - dice_loss: 0.2990
# Epoch 39: loss improved from 0.37584 to 0.34828, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.3483 - f1_score_metric: 0.4874 - dice_loss: 0.2990
# Epoch 40/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3476 - f1_score_metric: 0.4896 - dice_loss: 0.3005
# Epoch 40: loss improved from 0.34828 to 0.34759, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.3476 - f1_score_metric: 0.4896 - dice_loss: 0.3005
# Epoch 41/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3238 - f1_score_metric: 0.5079 - dice_loss: 0.2816
# Epoch 41: loss improved from 0.34759 to 0.32381, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.3238 - f1_score_metric: 0.5079 - dice_loss: 0.2816
# Epoch 42/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3132 - f1_score_metric: 0.5244 - dice_loss: 0.2706
# Epoch 42: loss improved from 0.32381 to 0.31316, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.3132 - f1_score_metric: 0.5244 - dice_loss: 0.2706
# Epoch 43/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3037 - f1_score_metric: 0.5382 - dice_loss: 0.2619
# Epoch 43: loss improved from 0.31316 to 0.30373, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.3037 - f1_score_metric: 0.5382 - dice_loss: 0.2619
# Epoch 44/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2814 - f1_score_metric: 0.5550 - dice_loss: 0.2427
# Epoch 44: loss improved from 0.30373 to 0.28143, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.2814 - f1_score_metric: 0.5550 - dice_loss: 0.2427
# Epoch 45/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2747 - f1_score_metric: 0.5655 - dice_loss: 0.2371
# Epoch 45: loss improved from 0.28143 to 0.27473, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.2747 - f1_score_metric: 0.5655 - dice_loss: 0.2371
# Epoch 46/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2637 - f1_score_metric: 0.5781 - dice_loss: 0.2281
# Epoch 46: loss improved from 0.27473 to 0.26374, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.2637 - f1_score_metric: 0.5781 - dice_loss: 0.2281
# Epoch 47/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2606 - f1_score_metric: 0.5863 - dice_loss: 0.2248
# Epoch 47: loss improved from 0.26374 to 0.26057, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.2606 - f1_score_metric: 0.5863 - dice_loss: 0.2248
# Epoch 48/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2387 - f1_score_metric: 0.6049 - dice_loss: 0.2067
# Epoch 48: loss improved from 0.26057 to 0.23868, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.2387 - f1_score_metric: 0.6049 - dice_loss: 0.2067
# Epoch 49/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2516 - f1_score_metric: 0.5942 - dice_loss: 0.2171
# Epoch 49: loss did not improve from 0.23868
# 16/16 [==============================] - 39s 2s/step - loss: 0.2516 - f1_score_metric: 0.5942 - dice_loss: 0.2171
# Epoch 50/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2247 - f1_score_metric: 0.6283 - dice_loss: 0.1936
# Epoch 50: loss improved from 0.23868 to 0.22468, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.2247 - f1_score_metric: 0.6283 - dice_loss: 0.1936
# Epoch 51/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2274 - f1_score_metric: 0.6241 - dice_loss: 0.1972
# Epoch 51: loss did not improve from 0.22468
# 16/16 [==============================] - 38s 2s/step - loss: 0.2274 - f1_score_metric: 0.6241 - dice_loss: 0.1972
# Epoch 52/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2090 - f1_score_metric: 0.6459 - dice_loss: 0.1810
# Epoch 52: loss improved from 0.22468 to 0.20898, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.2090 - f1_score_metric: 0.6459 - dice_loss: 0.1810
# Epoch 53/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2084 - f1_score_metric: 0.6469 - dice_loss: 0.1803
# Epoch 53: loss improved from 0.20898 to 0.20843, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.2084 - f1_score_metric: 0.6469 - dice_loss: 0.1803
# Epoch 54/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1993 - f1_score_metric: 0.6593 - dice_loss: 0.1722
# Epoch 54: loss improved from 0.20843 to 0.19935, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.1993 - f1_score_metric: 0.6593 - dice_loss: 0.1722
# Epoch 55/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1933 - f1_score_metric: 0.6696 - dice_loss: 0.1662
# Epoch 55: loss improved from 0.19935 to 0.19328, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1933 - f1_score_metric: 0.6696 - dice_loss: 0.1662
# Epoch 56/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1833 - f1_score_metric: 0.6790 - dice_loss: 0.1590
# Epoch 56: loss improved from 0.19328 to 0.18326, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1833 - f1_score_metric: 0.6790 - dice_loss: 0.1590
# Epoch 57/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1836 - f1_score_metric: 0.6805 - dice_loss: 0.1588
# Epoch 57: loss did not improve from 0.18326
# 16/16 [==============================] - 38s 2s/step - loss: 0.1836 - f1_score_metric: 0.6805 - dice_loss: 0.1588
# Epoch 58/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1732 - f1_score_metric: 0.6918 - dice_loss: 0.1500
# Epoch 58: loss improved from 0.18326 to 0.17315, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1732 - f1_score_metric: 0.6918 - dice_loss: 0.1500
# Epoch 59/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1671 - f1_score_metric: 0.7015 - dice_loss: 0.1442
# Epoch 59: loss improved from 0.17315 to 0.16711, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1671 - f1_score_metric: 0.7015 - dice_loss: 0.1442
# Epoch 60/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1676 - f1_score_metric: 0.7026 - dice_loss: 0.1451
# Epoch 60: loss did not improve from 0.16711
# 16/16 [==============================] - 38s 2s/step - loss: 0.1676 - f1_score_metric: 0.7026 - dice_loss: 0.1451
# Epoch 61/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1564 - f1_score_metric: 0.7144 - dice_loss: 0.1358
# Epoch 61: loss improved from 0.16711 to 0.15639, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.1564 - f1_score_metric: 0.7144 - dice_loss: 0.1358
# Epoch 62/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1591 - f1_score_metric: 0.7128 - dice_loss: 0.1384
# Epoch 62: loss did not improve from 0.15639
# 16/16 [==============================] - 38s 2s/step - loss: 0.1591 - f1_score_metric: 0.7128 - dice_loss: 0.1384
# Epoch 63/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1474 - f1_score_metric: 0.7325 - dice_loss: 0.1278
# Epoch 63: loss improved from 0.15639 to 0.14738, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1474 - f1_score_metric: 0.7325 - dice_loss: 0.1278
# Epoch 64/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1444 - f1_score_metric: 0.7382 - dice_loss: 0.1247
# Epoch 64: loss improved from 0.14738 to 0.14443, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.1444 - f1_score_metric: 0.7382 - dice_loss: 0.1247
# Epoch 65/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1398 - f1_score_metric: 0.7397 - dice_loss: 0.1209
# Epoch 65: loss improved from 0.14443 to 0.13976, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1398 - f1_score_metric: 0.7397 - dice_loss: 0.1209
# Epoch 66/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1372 - f1_score_metric: 0.7449 - dice_loss: 0.1187
# Epoch 66: loss improved from 0.13976 to 0.13717, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.1372 - f1_score_metric: 0.7449 - dice_loss: 0.1187
# Epoch 67/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1303 - f1_score_metric: 0.7578 - dice_loss: 0.1131
# Epoch 67: loss improved from 0.13717 to 0.13031, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.1303 - f1_score_metric: 0.7578 - dice_loss: 0.1131
# Epoch 68/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1273 - f1_score_metric: 0.7596 - dice_loss: 0.1107
# Epoch 68: loss improved from 0.13031 to 0.12730, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1273 - f1_score_metric: 0.7596 - dice_loss: 0.1107
# Epoch 69/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1242 - f1_score_metric: 0.7659 - dice_loss: 0.1080
# Epoch 69: loss improved from 0.12730 to 0.12422, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1242 - f1_score_metric: 0.7659 - dice_loss: 0.1080
# Epoch 70/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1242 - f1_score_metric: 0.7653 - dice_loss: 0.1078
# Epoch 70: loss did not improve from 0.12422
# 16/16 [==============================] - 38s 2s/step - loss: 0.1242 - f1_score_metric: 0.7653 - dice_loss: 0.1078
# Epoch 71/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1167 - f1_score_metric: 0.7753 - dice_loss: 0.1013
# Epoch 71: loss improved from 0.12422 to 0.11673, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1167 - f1_score_metric: 0.7753 - dice_loss: 0.1013
# Epoch 72/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1173 - f1_score_metric: 0.7780 - dice_loss: 0.1016
# Epoch 72: loss did not improve from 0.11673
# 16/16 [==============================] - 38s 2s/step - loss: 0.1173 - f1_score_metric: 0.7780 - dice_loss: 0.1016
# Epoch 73/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1136 - f1_score_metric: 0.7832 - dice_loss: 0.0987
# Epoch 73: loss improved from 0.11673 to 0.11362, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1136 - f1_score_metric: 0.7832 - dice_loss: 0.0987
# Epoch 74/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1105 - f1_score_metric: 0.7854 - dice_loss: 0.0958
# Epoch 74: loss improved from 0.11362 to 0.11054, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1105 - f1_score_metric: 0.7854 - dice_loss: 0.0958
# Epoch 75/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1051 - f1_score_metric: 0.7951 - dice_loss: 0.0917
# Epoch 75: loss improved from 0.11054 to 0.10507, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.1051 - f1_score_metric: 0.7951 - dice_loss: 0.0917
# Epoch 76/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1022 - f1_score_metric: 0.8004 - dice_loss: 0.0888
# Epoch 76: loss improved from 0.10507 to 0.10221, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.1022 - f1_score_metric: 0.8004 - dice_loss: 0.0888
# Epoch 77/100
# 16/16 [==============================] - ETA: 0s - loss: 0.1025 - f1_score_metric: 0.8027 - dice_loss: 0.0890
# Epoch 77: loss did not improve from 0.10221
# 16/16 [==============================] - 38s 2s/step - loss: 0.1025 - f1_score_metric: 0.8027 - dice_loss: 0.0890
# Epoch 78/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0997 - f1_score_metric: 0.8055 - dice_loss: 0.0867
# Epoch 78: loss improved from 0.10221 to 0.09970, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0997 - f1_score_metric: 0.8055 - dice_loss: 0.0867
# Epoch 79/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0965 - f1_score_metric: 0.8115 - dice_loss: 0.0834
# Epoch 79: loss improved from 0.09970 to 0.09645, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.0965 - f1_score_metric: 0.8115 - dice_loss: 0.0834
# Epoch 80/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0942 - f1_score_metric: 0.8186 - dice_loss: 0.0816
# Epoch 80: loss improved from 0.09645 to 0.09419, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0942 - f1_score_metric: 0.8186 - dice_loss: 0.0816
# Epoch 81/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0939 - f1_score_metric: 0.8170 - dice_loss: 0.0818
# Epoch 81: loss improved from 0.09419 to 0.09389, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0939 - f1_score_metric: 0.8170 - dice_loss: 0.0818
# Epoch 82/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0898 - f1_score_metric: 0.8247 - dice_loss: 0.0780
# Epoch 82: loss improved from 0.09389 to 0.08977, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0898 - f1_score_metric: 0.8247 - dice_loss: 0.0780
# Epoch 83/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0921 - f1_score_metric: 0.8184 - dice_loss: 0.0800
# Epoch 83: loss did not improve from 0.08977
# 16/16 [==============================] - 37s 2s/step - loss: 0.0921 - f1_score_metric: 0.8184 - dice_loss: 0.0800
# Epoch 84/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0886 - f1_score_metric: 0.8266 - dice_loss: 0.0768
# Epoch 84: loss improved from 0.08977 to 0.08858, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0886 - f1_score_metric: 0.8266 - dice_loss: 0.0768
# Epoch 85/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0856 - f1_score_metric: 0.8330 - dice_loss: 0.0744
# Epoch 85: loss improved from 0.08858 to 0.08556, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0856 - f1_score_metric: 0.8330 - dice_loss: 0.0744
# Epoch 86/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0831 - f1_score_metric: 0.8350 - dice_loss: 0.0723
# Epoch 86: loss improved from 0.08556 to 0.08307, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0831 - f1_score_metric: 0.8350 - dice_loss: 0.0723
# Epoch 87/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0836 - f1_score_metric: 0.8349 - dice_loss: 0.0729
# Epoch 87: loss did not improve from 0.08307
# 16/16 [==============================] - 38s 2s/step - loss: 0.0836 - f1_score_metric: 0.8349 - dice_loss: 0.0729
# Epoch 88/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0813 - f1_score_metric: 0.8407 - dice_loss: 0.0706
# Epoch 88: loss improved from 0.08307 to 0.08131, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0813 - f1_score_metric: 0.8407 - dice_loss: 0.0706
# Epoch 89/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0795 - f1_score_metric: 0.8399 - dice_loss: 0.0693
# Epoch 89: loss improved from 0.08131 to 0.07954, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.0795 - f1_score_metric: 0.8399 - dice_loss: 0.0693
# Epoch 90/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0816 - f1_score_metric: 0.8393 - dice_loss: 0.0707
# Epoch 90: loss did not improve from 0.07954
# 16/16 [==============================] - 38s 2s/step - loss: 0.0816 - f1_score_metric: 0.8393 - dice_loss: 0.0707
# Epoch 91/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0752 - f1_score_metric: 0.8499 - dice_loss: 0.0652
# Epoch 91: loss improved from 0.07954 to 0.07516, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0752 - f1_score_metric: 0.8499 - dice_loss: 0.0652
# Epoch 92/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0780 - f1_score_metric: 0.8457 - dice_loss: 0.0678
# Epoch 92: loss did not improve from 0.07516
# 16/16 [==============================] - 38s 2s/step - loss: 0.0780 - f1_score_metric: 0.8457 - dice_loss: 0.0678
# Epoch 93/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0756 - f1_score_metric: 0.8493 - dice_loss: 0.0656
# Epoch 93: loss did not improve from 0.07516
# 16/16 [==============================] - 38s 2s/step - loss: 0.0756 - f1_score_metric: 0.8493 - dice_loss: 0.0656
# Epoch 94/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0738 - f1_score_metric: 0.8536 - dice_loss: 0.0641
# Epoch 94: loss improved from 0.07516 to 0.07376, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 46s 3s/step - loss: 0.0738 - f1_score_metric: 0.8536 - dice_loss: 0.0641
# Epoch 95/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0702 - f1_score_metric: 0.8606 - dice_loss: 0.0608
# Epoch 95: loss improved from 0.07376 to 0.07020, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.0702 - f1_score_metric: 0.8606 - dice_loss: 0.0608
# Epoch 96/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0716 - f1_score_metric: 0.8580 - dice_loss: 0.0621
# Epoch 96: loss did not improve from 0.07020
# 16/16 [==============================] - 38s 2s/step - loss: 0.0716 - f1_score_metric: 0.8580 - dice_loss: 0.0621
# Epoch 97/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0686 - f1_score_metric: 0.8600 - dice_loss: 0.0596
# Epoch 97: loss improved from 0.07020 to 0.06862, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.0686 - f1_score_metric: 0.8600 - dice_loss: 0.0596
# Epoch 98/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0693 - f1_score_metric: 0.8621 - dice_loss: 0.0605
# Epoch 98: loss did not improve from 0.06862
# 16/16 [==============================] - 38s 2s/step - loss: 0.0693 - f1_score_metric: 0.8621 - dice_loss: 0.0605
# Epoch 99/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0667 - f1_score_metric: 0.8650 - dice_loss: 0.0583
# Epoch 99: loss improved from 0.06862 to 0.06673, saving model to checkpoints/best.weights.h5
# 16/16 [==============================] - 47s 3s/step - loss: 0.0667 - f1_score_metric: 0.8650 - dice_loss: 0.0583
# Epoch 100/100
# 16/16 [==============================] - ETA: 0s - loss: 0.0676 - f1_score_metric: 0.8653 - dice_loss: 0.0586
# Epoch 100: loss did not improve from 0.06673
# 16/16 [==============================] - 40s 3s/step - loss: 0.0676 - f1_score_metric: 0.8653 - dice_loss: 0.0586
# /home/nrr6650/dev/training/.venv/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### Prédictions

# %%
import matplotlib.pyplot as plt

# Récupération des données
acc = history.history['f1_score_metric']
# val_acc = history.history['val_f1_score_metric']
loss = history.history['loss']
# val_loss = history.history['val_loss']
epochs_range = range(len(acc))

# Création des graphiques
plt.figure(figsize=(14, 5))

# Précision
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train f1-score')
# plt.plot(epochs_range, val_acc, label='Val f1-score')
plt.title('F1-score over Epochs')
plt.xlabel('Epoch')
plt.ylabel('F1-score')
plt.legend(loc='lower right')

# Perte
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Loss')
# plt.plot(epochs_range, val_loss, label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

# Charger le modèle depuis le fichier .h5

model = load_model('unet_model_from_normals.h5', custom_objects={'focal_dice_loss': focal_dice_loss, 'f1_score_metric': f1_score_metric, 'dice_loss': dice_loss})

# Évaluation avec le générateur
loss, f1, _ = model.evaluate(test_gen)
print(f"Test Loss: {loss}, Test F1-score: {f1}")

# Prédiction sur quelques images du générateur
X_batch, y_batch = test_gen[0]  # Prend un batch
# X_batch, y_batch = train_gen[0]  # Prend un batch
preds = model.predict(X_batch)

import matplotlib.pyplot as plt

for i in range(min(5, X_batch.shape[0])):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.imshow((X_batch[i] + 1 )/2)  # Inverse normalization to [0, 2]
    plt.title("Normal Map")

    plt.subplot(1, 3, 2)
    plt.imshow(y_batch[i, ..., 0], cmap='gray')
    plt.title("Ground Truth")

    plt.subplot(1, 3, 3)
    plt.imshow(preds[i, ..., 0], cmap='gray')
    plt.title("Prediction")
    plt.show()
# Out:
# 2/2 [==============================] - 3s 788ms/step - loss: 0.0714 - f1_score_metric: 0.8609 - dice_loss: 0.0628
# Test Loss: 0.07135066390037537, Test F1-score: 0.8609226942062378
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# ### Fine Tuning avec des données annotées

# %%
MODEL_NAME = 'unet_model_from_normals_200ep.h5'

NEW_GROUNDTRUTH_FOLDER = 'dataset/dataset512_augmented/gravures_rot'
NEW_DATA_FOLDER = 'dataset/dataset512_augmented/murs_augmented'

BATCH_SIZE = 8

# %%
from tensorflow.keras.models import load_model
import os

# Charger le modèle existant
model = load_model(MODEL_NAME, custom_objects={'bce_dice_loss': focal_dice_loss, 'bce_dice_loss':bce_dice_loss, 'dice_loss': dice_loss, 'f1_score_metric': f1_score_metric})

# Générer les paires (similaire à la cellule 5)
new_groundtruth_files = sorted(os.listdir(NEW_GROUNDTRUTH_FOLDER))
new_data_files = sorted(os.listdir(NEW_DATA_FOLDER))

new_data_pairs = []
for gt_file in groundtruth_files:
  base_name = os.path.splitext(gt_file)[0]
  matching_data_files = [f for f in data_files if (f.startswith(base_name+"_") or f.startswith(base_name+"."))  and f.endswith('.png')]
  for file in matching_data_files:
    new_data_pairs.append((os.path.join(groundtruth_folder, gt_file), os.path.join(data_folder, file)))

print(f"Total new data pairs: {len(new_data_pairs)}")
# Créer un DataGenerator pour le fine-tuning
new_gen = DataGenerator(new_data_pairs, BATCH_SIZE, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, NEW_DATA_FOLDER, NEW_GROUNDTRUTH_FOLDER)

# Compiler le modèle pour le fine-tuning
adam3 = tf.keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.5, beta_2=0.5, epsilon=1e-07, amsgrad=False)
model.compile(
    optimizer=adam3,
    loss=focal_dice_loss,
    metrics=[f1_score_metric, dice_loss]
)
# Fine-tuning du modèle
model.fit(
    new_gen,
    epochs=10,  # Ajuste le nombre d'epochs selon tes besoins
    callbacks=[checkpoint, early_stopping]
)

# Sauvegarder le modèle fine-tuné
model.save('unet_model_finetuned.h5')
# Out:
# Total new data pairs: 2068
# Epoch 1/10
# 259/259 [==============================] - ETA: 0s - loss: 1.3968 - f1_score_metric: 0.0761 - dice_loss: 0.8220
# Epoch 1: loss improved from inf to 1.39678, saving model to checkpoints/best.weights.h5
# 259/259 [==============================] - 216s 824ms/step - loss: 1.3968 - f1_score_metric: 0.0761 - dice_loss: 0.8220
# Epoch 2/10
# 259/259 [==============================] - ETA: 0s - loss: 0.8402 - f1_score_metric: 0.0871 - dice_loss: 0.7846
# Epoch 2: loss improved from 1.39678 to 0.84018, saving model to checkpoints/best.weights.h5
# 259/259 [==============================] - 213s 822ms/step - loss: 0.8402 - f1_score_metric: 0.0871 - dice_loss: 0.7846
# Epoch 3/10
#  34/259 [==>...........................] - ETA: 3:04 - loss: 0.8367 - f1_score_metric: 0.0899 - dice_loss: 0.7805
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 30
#      24 model.compile(
#      25     optimizer=adam3,
#      26     loss=focal_dice_loss,
#      27     metrics=[f1_score_metric, dice_loss]
#      28 )
#      29 # Fine-tuning du modèle
# ---> 30 model.fit(
#      31     new_gen,
#      32     epochs=10,  # Ajuste le nombre d'epochs selon tes besoins
#      33     callbacks=[checkpoint, early_stopping]
#      34 )
#      36 # Sauvegarder le modèle fine-tuné
#      37 model.save('unet_model_finetuned.h5')
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/dev/training/.venv/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Utilisation sur des données réels

# %%
# l'image est redimensionnée à Height x Width
IMG_PATH = './omoplate.png'
MODEL_NAME = 'unet_model_from_normals_big_100ep.h5'
MODEL_WEIGHTS = 'checkpoints/best.weights.h5'

# charger le modèle avec les poids
model = load_model(MODEL_NAME, custom_objects={'focal_dice_loss': focal_dice_loss, 'f1_score_metric': f1_score_metric, 'dice_loss': dice_loss})
model.load_weights(MODEL_WEIGHTS)

# %%
# Charger et prétraiter la carte normale
carte_normale = load_img(IMG_PATH, target_size=(IMG_HEIGHT, IMG_WIDTH), color_mode="rgb")
carte_normale_arr = img_to_array(carte_normale) / 255.0
carte_normale_arr = np.expand_dims(carte_normale_arr, axis=0)  # shape: (1, H, W, 3)

# Prédiction du modèle
pred = model.predict(carte_normale_arr)[0]

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.imshow(carte_normale)
plt.title("Carte normale")

plt.subplot(1, 2, 2)
plt.imshow(pred, cmap='gray')
plt.title("Prediction")
plt.show()
# Out:
# 1/1 [==============================] - 0s 356ms/step
